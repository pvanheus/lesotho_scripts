# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data sources
# 1. sample_id_to_barcode - from make_mapping_file Notebook - from original spreadsheet that contains grid of sequence ids and barcodes
# 2. nextclade_report- from Nextclade run in Galaxy history 'batch1 consensus genomes 2' (consensus genomes with non-N at depth >= 20 and AF >= 0.8)
# 3. sequence_mapping_report - exported from MultiQC table of Galaxy 'batch 1' analysis
# 4. spreadsheet_with_metadata - Excel spreadsheet with patient metadata and sample IDs

# %%
barcode_sampleid_mapping_df = pd.read_csv('data/sample_id_to_barcode.csv', dtype={'sample_id': 'str'})
nextclade_df = pd.read_csv('data/nextclade_report.tsv', delimiter='\t')
nextclade_qc_columns = [ col for col in nextclade_df.columns if col.startswith('qc.') or col.startswith('total') ]
nextclade_qc_df = pd.read_csv('data/nextclade_report.tsv', delimiter='\t', usecols=['seqName', 'clade'] + nextclade_qc_columns) 
sequence_mapping_df = pd.read_csv('data/sequence_mapping_report.tsv', delimiter='\t', 
                                  usecols=['Sample Name', '≥ 30X', 'Median cov', 'Mean cov', 'M Reads Mapped']).rename({'Sample Name': 'seqName'}, axis=1)

# %%
nextclade_qc_df.set_index('seqName')
# Out:
#                    clade  qc.overallScore qc.overallStatus  \
# seqName
# barcode50  21K (Omicron)      1959.456187              bad
# barcode72  21L (Omicron)        97.170374         mediocre
# barcode80  21L (Omicron)        93.009520         mediocre
# barcode71  21L (Omicron)       126.902689              bad
# barcode64  21L (Omicron)       150.609290              bad
# barcode76  21K (Omicron)      1981.835971              bad
# barcode89  21K (Omicron)      5065.413172              bad
# barcode78  21L (Omicron)       406.504993              bad
# barcode73  21K (Omicron)         0.000000             good
# barcode85  21K (Omicron)      3981.598985              bad
# barcode90  21K (Omicron)      2036.623457              bad
# barcode58  21K (Omicron)        63.341372         mediocre
# barcode87  21K (Omicron)      9807.558642              bad
# barcode92  21K (Omicron)      4959.272431              bad
# barcode88  21K (Omicron)      7857.856999              bad
# barcode91  21K (Omicron)      6296.889057              bad
# barcode77  21K (Omicron)       262.203090              bad
# barcode65  21K (Omicron)      8372.417781              bad
# barcode67  21K (Omicron)         1.044938             good
# barcode79  21K (Omicron)       656.016063              bad
# barcode52  21L (Omicron)        10.144376             good
# barcode54  21K (Omicron)       226.007421              bad
# barcode66  21K (Omicron)        71.246104         mediocre
# barcode55  21K (Omicron)       152.752401              bad
# barcode93  21K (Omicron)      3475.061389              bad
# barcode84  21K (Omicron)     11396.209674              bad
# barcode63  21K (Omicron)       225.296420              bad
# barcode74  21K (Omicron)         0.000000             good
# barcode69  21K (Omicron)         1.953827             good
# barcode68  21K (Omicron)        63.420494         mediocre
# barcode86  21K (Omicron)     12927.851883              bad
# barcode57  21K (Omicron)         7.111111             good
# barcode70  21K (Omicron)        12.279753             good
# barcode60  21K (Omicron)         7.170494             good
# barcode61  21K (Omicron)      6737.154444              bad
# barcode81  21M (Omicron)     14967.237246              bad
# barcode51  21K (Omicron)        59.776049         mediocre
# barcode56  21K (Omicron)       228.807627              bad
# barcode83  21L (Omicron)     11547.423611              bad
# barcode94  21K (Omicron)      5179.449674              bad
# barcode96  21K (Omicron)      5586.012308              bad
# barcode53  21K (Omicron)        43.072483         mediocre
# barcode62  21K (Omicron)       522.581084              bad
# barcode59  21K (Omicron)         7.071660             good
# barcode75  21K (Omicron)         6.213018             good
# barcode82  21K (Omicron)      7938.903735              bad
# barcode95  21K (Omicron)     22419.337791              bad
#
#            totalSubstitutions  totalDeletions  totalInsertions  \
# seqName
# barcode50                  60              10               34
# barcode72                  64              18                2
# barcode80                  60              18                1
# barcode71                  68              18                2
# barcode64                  57              18                1
# barcode76                  45              14                8
# barcode89                  41               2               15
# barcode78                  61              18                9
# barcode73                  53              39                9
# barcode85                  62               0               22
# barcode90                  41              11               12
# barcode58                  48              29                9
# barcode87                  63              14               51
# barcode92                  64               1               41
# barcode88                  66               2               60
# barcode91                  82               9               69
# barcode77                  50              12                2
# barcode65                  56               1               44
# barcode67                  53              30                9
# barcode79                  64              13               20
# barcode52                  67              27                0
# barcode54                  55              31               12
# barcode66                  52              12                9
# barcode55                  50              27               10
# barcode93                  65              12               33
# barcode84                  73               0               53
# barcode63                  54              37                9
# barcode74                  56              39                9
# barcode69                  55              30               11
# barcode68                  50              29                9
# barcode86                  82               0               54
# barcode57                  54              30                9
# barcode70                  55              30                9
# barcode60                  51              30                9
# barcode61                  68               0               41
# barcode81                  95               1               82
# barcode51                  53              29                9
# barcode56                  58              38                9
# barcode83                  98               0               60
# barcode94                  58               5               12
# barcode96                  63               1               63
# barcode53                  46              30                9
# barcode62                  64              12               34
# barcode59                  51              30                9
# barcode75                  50              30                9
# barcode82                  96               1               65
# barcode95                 124               2              145
#
#            totalFrameShifts  totalAminoacidSubstitutions  \
# seqName
# barcode50                 4                           32
# barcode72                 1                           47
# barcode80                 1                           43
# barcode71                 1                           47
# barcode64                 1                           46
# barcode76                 4                           11
# barcode89                 4                            6
# barcode78                 1                           35
# barcode73                 0                           46
# barcode85                 3                           12
# barcode90                 3                           24
# barcode58                 1                           15
# barcode87                 7                            2
# barcode92                 6                           22
# barcode88                 7                            4
# barcode91                 8                           25
# barcode77                 2                           31
# barcode65                 9                            3
# barcode67                 0                           45
# barcode79                 3                           35
# barcode52                 0                           51
# barcode54                 2                           44
# barcode66                 0                           37
# barcode55                 1                           35
# barcode93                 7                           11
# barcode84                 8                            2
# barcode63                 2                           45
# barcode74                 0                           47
# barcode69                 0                           45
# barcode68                 1                           17
# barcode86                 8                            4
# barcode57                 0                           45
# barcode70                 0                           45
# barcode60                 0                           42
# barcode61                 5                            4
# barcode81                 7                            2
# barcode51                 1                           15
# barcode56                 2                           45
# barcode83                 7                            6
# barcode94                 4                            6
# barcode96                 8                           26
# barcode53                 0                           38
# barcode62                 3                           16
# barcode59                 0                           43
# barcode75                 0                           43
# barcode82                 9                           11
# barcode95                15                            1
#
#            totalAminoacidDeletions  totalAminoacidInsertions  ...  \
# seqName                                                       ...
# barcode50                        3                         3  ...
# barcode72                        6                         0  ...
# barcode80                        6                         0  ...
# barcode71                        6                         0  ...
# barcode64                        6                         0  ...
# barcode76                        2                         0  ...
# barcode89                        0                         1  ...
# barcode78                        3                         0  ...
# barcode73                       16                         1  ...
# barcode85                        0                         3  ...
# barcode90                        2                         1  ...
# barcode58                        9                         0  ...
# barcode87                        0                         3  ...
# barcode92                        0                         2  ...
# barcode88                        1                         3  ...
# barcode91                        1                         3  ...
# barcode77                        0                         0  ...
# barcode65                        0                         1  ...
# barcode67                       10                         1  ...
# barcode79                        4                         1  ...
# barcode52                       12                         0  ...
# barcode54                       11                         2  ...
# barcode66                        4                         1  ...
# barcode55                        6                         1  ...
# barcode93                        4                         1  ...
# barcode84                        0                         3  ...
# barcode63                       14                         1  ...
# barcode74                       16                         1  ...
# barcode69                       10                         1  ...
# barcode68                        9                         0  ...
# barcode86                        0                         2  ...
# barcode57                       10                         1  ...
# barcode70                       10                         1  ...
# barcode60                       10                         1  ...
# barcode61                        0                         2  ...
# barcode81                        1                         7  ...
# barcode51                        6                         0  ...
# barcode56                       16                         1  ...
# barcode83                        0                         3  ...
# barcode94                        1                         1  ...
# barcode96                        0                         2  ...
# barcode53                       10                         1  ...
# barcode62                        4                         1  ...
# barcode59                       10                         1  ...
# barcode75                       10                         1  ...
# barcode82                        0                         6  ...
# barcode95                        1                         6  ...
#
#                                   qc.frameShifts.frameShifts  \
# seqName
# barcode50  ORF1a:698-1377,ORF1a:1672-2333,ORF1a:4366-4401...
# barcode72                                    ORF1b:2445-2696
# barcode80                                          N:143-420
# barcode71                                    ORF1b:2487-2696
# barcode64                                    ORF1b:2577-2696
# barcode76  ORF1a:2337-2389,ORF1a:3366-4401,ORF1b:750-2696...
# barcode89  ORF1a:456-1310,ORF1a:3422-4401,ORF1b:823-2696,...
# barcode78                                      ORF1a:27-4401
# barcode73                                                NaN
# barcode85               ORF1a:1353-1423,S:323-500,S:917-1274
# barcode90     ORF1a:691-2083,ORF1a:3122-3757,ORF1a:4063-4401
# barcode58                                         S:145-1274
# barcode87  M:145-223,ORF1a:1650-4401,ORF1b:301-341,ORF1b:...
# barcode92  ORF1a:857-1824,ORF1a:3448-4401,ORF1b:2534-2696...
# barcode88  N:136-420,ORF1a:127-1423,ORF1a:1428-3447,ORF1a...
# barcode91  N:303-366,ORF1a:137-3891,ORF1b:1466-1544,ORF1b...
# barcode77                           N:143-420,ORF1a:924-4401
# barcode65  M:118-122,M:189-223,N:139-420,ORF1a:792-848,OR...
# barcode67                                                NaN
# barcode79                      S:33-302,S:684-719,S:923-1274
# barcode52                                                NaN
# barcode54                               N:31-420,ORF9b:27-98
# barcode66                                                NaN
# barcode55                                    ORF1a:2045-4401
# barcode93  ORF1a:3769-4401,S:66-186,S:215-695,S:731-855,S...
# barcode84  ORF1a:2182-2336,ORF1a:2376-3992,ORF1a:4050-440...
# barcode63                               N:33-420,ORF9b:30-98
# barcode74                                                NaN
# barcode69                                                NaN
# barcode68                                         S:145-1274
# barcode86  ORF1a:88-168,ORF1a:242-287,ORF1a:885-1051,ORF1...
# barcode57                                                NaN
# barcode70                                                NaN
# barcode60                                                NaN
# barcode61  ORF1a:4378-4401,ORF1b:13-758,ORF1b:1279-2325,S...
# barcode81  ORF1a:545-2880,ORF1a:3862-3876,ORF1b:1007-1419...
# barcode51                                          S:70-1274
# barcode56                               N:33-420,ORF9b:30-98
# barcode83  N:319-353,N:408-420,ORF1a:102-2562,ORF1a:4159-...
# barcode94  ORF1a:3060-4401,ORF1b:315-2313,ORF1b:2660-2696...
# barcode96  M:198-215,N:143-420,ORF1a:2257-3071,ORF1a:3075...
# barcode53                                                NaN
# barcode62                        S:81-83,S:91-299,S:320-1274
# barcode59                                                NaN
# barcode75                                                NaN
# barcode82  ORF1a:121-1394,ORF1a:4054-4401,ORF1b:57-294,OR...
# barcode95  M:64-223,ORF1a:131-1383,ORF1a:1491-1675,ORF1a:...
#
#            qc.frameShifts.totalFrameShifts  qc.frameShifts.frameShiftsIgnored  \
# seqName
# barcode50                                4                                NaN
# barcode72                                1                                NaN
# barcode80                                1                                NaN
# barcode71                                1                                NaN
# barcode64                                1                                NaN
# barcode76                                4                                NaN
# barcode89                                4                                NaN
# barcode78                                1                                NaN
# barcode73                                0                                NaN
# barcode85                                3                                NaN
# barcode90                                3                                NaN
# barcode58                                1                                NaN
# barcode87                                7                                NaN
# barcode92                                6                                NaN
# barcode88                                6                       ORF7a:83-122
# barcode91                                8                                NaN
# barcode77                                2                                NaN
# barcode65                                9                                NaN
# barcode67                                0                                NaN
# barcode79                                3                                NaN
# barcode52                                0                                NaN
# barcode54                                2                                NaN
# barcode66                                0                                NaN
# barcode55                                1                                NaN
# barcode93                                7                                NaN
# barcode84                                8                                NaN
# barcode63                                2                                NaN
# barcode74                                0                                NaN
# barcode69                                0                                NaN
# barcode68                                1                                NaN
# barcode86                                8                                NaN
# barcode57                                0                                NaN
# barcode70                                0                                NaN
# barcode60                                0                                NaN
# barcode61                                5                                NaN
# barcode81                                7                                NaN
# barcode51                                1                                NaN
# barcode56                                2                                NaN
# barcode83                                7                                NaN
# barcode94                                4                                NaN
# barcode96                                8                                NaN
# barcode53                                0                                NaN
# barcode62                                3                                NaN
# barcode59                                0                                NaN
# barcode75                                0                                NaN
# barcode82                                8                        ORF7b:13-44
# barcode95                               15                                NaN
#
#            qc.frameShifts.totalFrameShiftsIgnored  qc.frameShifts.score  \
# seqName
# barcode50                                       0                 300.0
# barcode72                                       0                  75.0
# barcode80                                       0                  75.0
# barcode71                                       0                  75.0
# barcode64                                       0                  75.0
# barcode76                                       0                 300.0
# barcode89                                       0                 300.0
# barcode78                                       0                  75.0
# barcode73                                       0                   0.0
# barcode85                                       0                 225.0
# barcode90                                       0                 225.0
# barcode58                                       0                  75.0
# barcode87                                       0                 525.0
# barcode92                                       0                 450.0
# barcode88                                       1                 450.0
# barcode91                                       0                 600.0
# barcode77                                       0                 150.0
# barcode65                                       0                 675.0
# barcode67                                       0                   0.0
# barcode79                                       0                 225.0
# barcode52                                       0                   0.0
# barcode54                                       0                 150.0
# barcode66                                       0                   0.0
# barcode55                                       0                  75.0
# barcode93                                       0                 525.0
# barcode84                                       0                 600.0
# barcode63                                       0                 150.0
# barcode74                                       0                   0.0
# barcode69                                       0                   0.0
# barcode68                                       0                  75.0
# barcode86                                       0                 600.0
# barcode57                                       0                   0.0
# barcode70                                       0                   0.0
# barcode60                                       0                   0.0
# barcode61                                       0                 375.0
# barcode81                                       0                 525.0
# barcode51                                       0                  75.0
# barcode56                                       0                 150.0
# barcode83                                       0                 525.0
# barcode94                                       0                 300.0
# barcode96                                       0                 600.0
# barcode53                                       0                   0.0
# barcode62                                       0                 225.0
# barcode59                                       0                   0.0
# barcode75                                       0                   0.0
# barcode82                                       1                 600.0
# barcode95                                       0                1125.0
#
#           qc.frameShifts.status  qc.stopCodons.stopCodons  \
# seqName
# barcode50                   bad                       NaN
# barcode72              mediocre                       NaN
# barcode80              mediocre                       NaN
# barcode71              mediocre                       NaN
# barcode64              mediocre                     N:135
# barcode76                   bad                       NaN
# barcode89                   bad                       NaN
# barcode78              mediocre                       NaN
# barcode73                  good                       NaN
# barcode85                   bad                       NaN
# barcode90                   bad                       NaN
# barcode58              mediocre                       NaN
# barcode87                   bad                       NaN
# barcode92                   bad                       NaN
# barcode88                   bad                       NaN
# barcode91                   bad                       NaN
# barcode77                   bad                       NaN
# barcode65                   bad                       NaN
# barcode67                  good                       NaN
# barcode79                   bad                       NaN
# barcode52                  good                       NaN
# barcode54                   bad                       NaN
# barcode66                  good                       NaN
# barcode55              mediocre                       NaN
# barcode93                   bad                       NaN
# barcode84                   bad                       NaN
# barcode63                   bad                       NaN
# barcode74                  good                       NaN
# barcode69                  good                       NaN
# barcode68              mediocre                       NaN
# barcode86                   bad                       NaN
# barcode57                  good                       NaN
# barcode70                  good                       NaN
# barcode60                  good                       NaN
# barcode61                   bad                       NaN
# barcode81                   bad                       NaN
# barcode51              mediocre                       NaN
# barcode56                   bad                       NaN
# barcode83                   bad                       NaN
# barcode94                   bad                       NaN
# barcode96                   bad                       NaN
# barcode53                  good                       NaN
# barcode62                   bad                       NaN
# barcode59                  good                       NaN
# barcode75                  good                       NaN
# barcode82                   bad                       NaN
# barcode95                   bad                       NaN
#
#            qc.stopCodons.totalStopCodons  qc.stopCodons.score  \
# seqName
# barcode50                              0                  0.0
# barcode72                              0                  0.0
# barcode80                              0                  0.0
# barcode71                              0                  0.0
# barcode64                              1                 75.0
# barcode76                              0                  0.0
# barcode89                              0                  0.0
# barcode78                              0                  0.0
# barcode73                              0                  0.0
# barcode85                              0                  0.0
# barcode90                              0                  0.0
# barcode58                              0                  0.0
# barcode87                              0                  0.0
# barcode92                              0                  0.0
# barcode88                              0                  0.0
# barcode91                              0                  0.0
# barcode77                              0                  0.0
# barcode65                              0                  0.0
# barcode67                              0                  0.0
# barcode79                              0                  0.0
# barcode52                              0                  0.0
# barcode54                              0                  0.0
# barcode66                              0                  0.0
# barcode55                              0                  0.0
# barcode93                              0                  0.0
# barcode84                              0                  0.0
# barcode63                              0                  0.0
# barcode74                              0                  0.0
# barcode69                              0                  0.0
# barcode68                              0                  0.0
# barcode86                              0                  0.0
# barcode57                              0                  0.0
# barcode70                              0                  0.0
# barcode60                              0                  0.0
# barcode61                              0                  0.0
# barcode81                              0                  0.0
# barcode51                              0                  0.0
# barcode56                              0                  0.0
# barcode83                              0                  0.0
# barcode94                              0                  0.0
# barcode96                              0                  0.0
# barcode53                              0                  0.0
# barcode62                              0                  0.0
# barcode59                              0                  0.0
# barcode75                              0                  0.0
# barcode82                              0                  0.0
# barcode95                              0                  0.0
#
#           qc.stopCodons.status
# seqName
# barcode50                 good
# barcode72                 good
# barcode80                 good
# barcode71                 good
# barcode64             mediocre
# barcode76                 good
# barcode89                 good
# barcode78                 good
# barcode73                 good
# barcode85                 good
# barcode90                 good
# barcode58                 good
# barcode87                 good
# barcode92                 good
# barcode88                 good
# barcode91                 good
# barcode77                 good
# barcode65                 good
# barcode67                 good
# barcode79                 good
# barcode52                 good
# barcode54                 good
# barcode66                 good
# barcode55                 good
# barcode93                 good
# barcode84                 good
# barcode63                 good
# barcode74                 good
# barcode69                 good
# barcode68                 good
# barcode86                 good
# barcode57                 good
# barcode70                 good
# barcode60                 good
# barcode61                 good
# barcode81                 good
# barcode51                 good
# barcode56                 good
# barcode83                 good
# barcode94                 good
# barcode96                 good
# barcode53                 good
# barcode62                 good
# barcode59                 good
# barcode75                 good
# barcode82                 good
# barcode95                 good
#
# [47 rows x 40 columns]

# %%
# NB
# convert the metadata from CIFs to metadata relevant to GISAID

def convert_gender(g):
    if g == 'm':
        return 'Male'
    elif g == 'f':
        return 'Female'
    else:
        return 'Unknown'
    
def convert_district(d):
    d = d.replace("'", "")
    if ' ' in d:
        fields = d.split()
        d = ' '.join([field.capitalize() for field in fields])
    else:
        d = d.capitalize()
    if d == 'Butha Bothe':
        d = 'Butha Buthe'
    return d

patient_metadata = pd.read_excel('data/spreadsheet_with_metadata.xlsx', sheet_name='Sheet3', 
                                 converters = {'Sample ID': lambda s: str(s),
                                               'Gender':  convert_gender,
                                               'District': convert_district}).rename({'Sample ID': 'sample_id'}, axis=1)
patient_metadata.columns
patient_metadata_subset = patient_metadata[['sample_id', 'specimen collection', 'Specimen Type', 'District',
                                            'qPCR Result Date', 'CT Value N GENE', 'CT Value ORF GENE']]

# this is a subset oriented around submission to GISAID - less relevant for assessing sample quality
# patient_metadata_subset = patient_metadata[['sample_id', 'specimen collection', 'Specimen Type', 'Purpose of Sampling', 'Age', 'Gender', 'District',
#                                             'qPCR Result Date', 'CT Value N GENE', 'CT Value ORF GENE']]
# now = pd.Timestamp('now')
# patient_metadata_subset.insert(len(patient_metadata_subset.columns), 'age', (now - patient_metadata_subset['Age']).astype('<m8[Y]').replace(-1, np.nan))
# patient_metadata_subset = patient_metadata_subset.drop('Age', axis=1)
patient_metadata_subset.insert(len(patient_metadata_subset.columns), 'days to PCR result', patient_metadata_subset['qPCR Result Date'] - patient_metadata_subset['specimen collection'])

# %%
patient_info_with_barcodes = patient_metadata_subset.set_index('sample_id').join(barcode_sampleid_mapping_df.set_index('sample_id')).reset_index()
patient_info_with_barcodes_and_mapping_info = patient_info_with_barcodes.set_index('seqName').join(sequence_mapping_df.set_index('seqName'))
combined_df = patient_info_with_barcodes_and_mapping_info.join(nextclade_qc_df.set_index('seqName')).reset_index()
combined_df.to_excel('data/combined_qc_info.xlsx')
